# %% [markdown]
# https://www.youtube.com/watch?v=quAS1iydq7U
#
# https://leetcode.com/problems/next-permutation/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## not working
class Solution(object):
    def nextPermutation(self, nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        n=last_val = len(nums)-1
        
        pivot = 0
        
        while nums[n-1]>nums[n] and n>0:
            n-=1
            print(nums[n])
            pivot=n-1
            print(pivot)
        if pivot ==0:
            return
        print(nums[pivot])
        
        n=last_val
        while(nums[pivot]>nums[n]):
            n-=1
        temp = nums[pivot]
        nums[pivot] = nums[n]
        nums[n] = temp
        print(pivot)
        print(nums)
        nums[pivot+1:len(nums)] = nums[pivot+1:len(nums)][::-1]
        print(nums)

# %%
class Solution(object):
    def nextPermutation(self, nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        n=last_val = len(nums)-1
        
        while nums[n-1]>=nums[n] and n>0:
            n-=1
            print('n',n)
        pivot = n
        if pivot ==0:
            nums=nums[::-1]
            print(nums)
        else:
            print(nums[pivot])

            n=last_val
            while(nums[pivot-1]>nums[n]):
                n-=1
            temp = nums[pivot-1]
            nums[pivot-1] = nums[n]
            nums[n] = temp
            print(pivot)
            print(nums)
            nums[pivot:len(nums)] = nums[pivot:len(nums)][::-1]
            print(nums)

# %%
s = Solution()

# %%
# s.nextPermutation(nums=[1,3,5,4,2,1])
# s.nextPermutation(nums=[1,2,3])
s.nextPermutation(nums=[3,2,1])
# Out:
# n 1
# n 0
# [1, 2, 3]
