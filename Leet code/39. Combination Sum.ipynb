# %% [markdown]
# https://leetcode.com/problems/combination-sum/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution(object):
    def combinationSum(self, candidates, target):
        """
        :type candidates: List[int]
        :type target: int
        :rtype: List[List[int]]
        """
        result=[]
        self.dfs(candidates,target,[],result)
        return(result)
    def dfs(self,nums,target,curr_set,result):
        if(target==0):
            result.append(curr_set)
            return
        if(target<0):
            return
        for i in range(len(nums)):
            self.dfs(nums[i:],target-nums[i],curr_set+[nums[i]],result)

# %%
candidates = [2,3,6,7] 
target = 7
temp = []
main_list = []
for c in candidates:
    temp=[]
    while(sum(temp)<target):
        temp.append(c)
    print(temp)
    if(sum(temp)==target):
        main_list.append(temp)
print(main_list)
# Out:
# [2, 2, 2, 2]
# [3, 3, 3]
# [6, 6]
# [7]
# [[7]]

# %%
class Solution(object):
    def combinationSum(self, candidates, target):
        ret = []
        dict_temp=dict()
        self.dfs(candidates, target, [], ret)
        return ret
    
    def dfs(self, nums, target, path, ret):
        if target < 0:
            return 
        if target == 0:
            
            ret.append(path)
            return 
        for i in range(len(nums)):
            print(nums[i:], target-nums[i], path+[nums[i]], ret)
            self.dfs(nums[i:], target-nums[i], path+[nums[i]], ret)

# %%
([2,3,6,7],5,[2],[])
([2,3,6,7],3,[2,2],[])
([2,3,6,7],1,[2,2,2],[])
([2,3,6,7],-1,[2,2,2,2],[])
# Out:
# ([2, 3, 6, 7], -1, [2, 2, 2, 2], [])

# %%
s=Solution()

# %%
s.combinationSum(candidates, target)
# Out:
# [[2, 2, 3], [7]]

# %%
[2,3,6,7]
